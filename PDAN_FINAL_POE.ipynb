# %% [markdown]
# ##  **IMAGE CLASSIFICATION**

# %% [markdown]
# **What is Image Classification?**

# %% [markdown]
# "*Image classification refers to the task of extracting information classes from a multiband raster image. The resulting raster from image classification can be used to create thematic maps. Depending on the interaction between the analyst and the computer during classification, there are two types of classification: supervised and unsupervised. Supervised classification uses the spectral signatures obtained from training samples to classify an image. While, unsupervised classification finds spectral classes (or clusters) in a multiband image without the analyst’s intervention.*" (*What is image classification?*, ArcMap)
# <br>
# <br>
# <br>
# **Reference:**<br>
# ArcMap. *What is image classification?*<br>
# [Online] Available at:<br>
# https://desktop.arcgis.com/en/arcmap/latest/extensions/spatial-analyst/image-classification/what-is-image-classification-.htm <br>
# [Accessed 08 November 2023]

# %% [markdown]
# **Advantages & Disadvantages**

# %% [markdown]
# Advantages:
#
# - "*In supervised classification, the operator can often detect and rectify images.*" (*7: Supervised and Unsupervised Image Classification*, wordpress)
# <br>
# - "*In supervised classification, the analyst has control.*" (*7: Supervised and Unsupervised Image Classification*, wordpress)
# <br>
# - "*In unsupervised classification, no prior knowledge of the region is required.*" (*7: Supervised and Unsupervised Image Classification*, wordpress)
# <br>
# - "*In supervised classification, allows for minimisation of human error.*" (*7: Supervised and Unsupervised Image Classification*, wordpress)
# <br>
#
# Disadvantages:
#
# - "*Intra-Class Variation is when the difference in images from the same class.*" (*5 Common Problems With Working On Real World Image Data*, Bayshore Intelligent Solutions)
# <br>
# - "*Clutter in the background signifies that the image contains a large number of things, making it difficult for the observer to locate the desired object.*" (*5 Common Problems With Working On Real World Image Data*, Bayshore Intelligent Solutions)
# <br>
# - "*Scale variation is a typical issue in image classification where it refers to having too many images of the same subject at different sizes.*" (*5 Common Problems With Working On Real World Image Data*, Bayshore Intelligent Solutions)
# <br>
# <br>
#
#
# **Reference:**<br>
# wordpress. *7: Supervised and Unsupervised Image Classification*<br>
# [Online] Available at:<br>
# https://myremotesensingblog.wordpress.com/2014/12/02/7-supervised-and-unsupervised-image-classification/ <br>
# [Accessed 08 November 2023]
# <br>
# <br>
# <br>
#
# Bayshore Intelligent Solutions. *5 Common Problems With Working On Real World Image Data*<br>
# [Online] Available at:<br>
# https://bayshoreintel.com/5-common-problems-with-working-on-real-world-image-data <br>
# [Accessed 08 November 2023]

# %% [markdown]
# **Real-world Applications of Image Classification**

# %% [markdown]
# Here are some real-world applications of where Image Classification is typically used in:
#
# - "*Face recognition in security*" (*A Complete Guide to Image Classification in 2023*, COMPUTER VISION)
# - "*Traffic monitoring and congestion detection*" (*A Complete Guide to Image Classification in 2023*, COMPUTER VISION)
# - "*Detection of cancer cells in pathology slides*" (*A Complete Guide to Image Classification in 2023*, COMPUTER VISION)
# - "*Object recognition in driverless cars*" (*A Complete Guide to Image Classification in 2023*, COMPUTER VISION)
# - "*Retail customer segmentation*" (*A Complete Guide to Image Classification in 2023*, COMPUTER VISION)
# - "*Automated inspection and quality control*" (*A Complete Guide to Image Classification in 2023*, COMPUTER VISION)
# <br>
# <br>
#
#
# **Reference:**<br>
# COMPUTER VISION. *A Complete Guide to Image Classification in 2023*<br>
# [Online] Available at:<br>
# https://viso.ai/computer-vision/image-classification/#:~:text=Image%20classification%20is%20probably%20the,example%2C%20in%20face%20recognition). <br>
# [Accessed 08 November 2023]

# %% [markdown]
# ##  **DATASET**

# %% [markdown]
# *What dataset is used in this analysis?* I've chosen the **CIFAKE: Real and AI-Generated Synthetic Images** dataset. (Bird, 2023)
#
# *Why is this dataset perfect for Image Classification?* Let's start of by saying what type of data does this dataset provide. This dataset is made up completely of images, and comprises of two main folders that seperate the train and test image data. Within each folder has two sub folders for the fake and real images. These images have been updated from a .jpeg to a .jpg format. The goal of this dataset, came when the creator felt that as technology and AI continues to advance, the rise in AI generated images will lead to concerns of authenticity and trustworthiness. Therefore, this dataset is perfect for the image classification analysis that would be conducted on it. This dataset is also perfect for our analysis because it is already split into the training and test portions, and also the size of the dataset comprises of a total of 120 000 images with fairly new and updated data. It should also be said that this dataset is relevant to the field of IT, and the creator has even published a paper using this dataset called *'CIFAKE: Image Classification and Explainable Identification of AI-Generated Synthetic Images'*, and made it publicly available to the research community for future work.
# <br>
# <br>
# **Reference for Dataset**
#
# Bird, J.J.(2023) *'CIFAKE: Real and AI-Generated Synthetic Images'*. [Online]. Available at:<br>
# https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images<br>
# [Accessed 14 November 2023]

# %% [markdown]
# ## **ANALYSIS**

# %% [markdown]
# "*A convolutional neural network (CNN) is a subset of machine learning. It is one of the various types of artificial neural networks which are used for different applications and data types. A CNN is a kind of network architecture for deep learning algorithms and is specifically used for image recognition and tasks that involve the processing of pixel data. There are other types of neural networks in deep learning, but for identifying and recognizing objects, CNNs are the network architecture of choice. This makes them highly suitable for computer vision (CV) tasks and for applications where object recognition is vital, such as self-driving cars and facial recognition.*" ("*convolutional neural network (CNN)*", Tech Target)
# <br>
# <br>
# <br>
# **Reference:**<br>
# Tech Target. *convolutional neural network (CNN)*<br>
# [Online] Available at:<br>
# https://www.techtarget.com/searchenterpriseai/definition/convolutional-neural-network <br>
# [Accessed 19 November 2023]

# %% [markdown]
# ## **STEPS IN THE ANALYSIS**

# %% [markdown]
# ***What Steps should be included in this Analysis for:***<br><br>
# - ***Loading the Dataset:*** this step is pretty self explanatory, we will load the dataset by downloading it directly from Kaggle. First, we'll connect to Google Drive; then get our Kaggle account details by downloading the kaggle.json file; and then connecting to Kaggle and downloading the dataset from there. Since, this dataset is made up of images, there wasn't any EDA or data wrangling needed. However, we can talk about how the images were seperated into the train and test portions. For train, it comprised of 100 000 images (50 000 per class), while 20 000 images were for testing (10 000 per class).
# <br><br>
#
# - ***Image Generators:*** for the image generators, we will use Tensorflow and Keras. Tensorflow is a useful tool in image proceessing, specifically TensorFlow is a robust deep learning framework, and Keras is a high-level API that provides a modular, easy-to-use, and organised interface to solve real-life deep learning problems. In this step, we'll create and call two methods, one for the train generator and the other for the test generator.
# <br><br>
#
# - ***Convolutional Neural Network (CNN):*** is this step, we'll build and fit the CNN Model. We use a CNN because it is useful in finding patterns in images to recognise objects, classes, and categories. Therefore, we can say a CNN is our discriminator that takes an image and its respective target image and gives probability value for its similarity. This step is pretty self explanatory, and we can hypertune our model by fitting it with 10 epochs. When increasing the number of epochs in an image classification model, you don't want your model to learn the exact images (overfit), but you want your model to learn the images's features and adjust the weights accordingly in order to generalise your model and make it applicable to other images of the same type outside your training set. Some other ways we can counter the problem of overfitting is implementing data augmentation and dropout regularisation.
# <br><br>
#
# - ***Model Evaluation:*** in this step we display the train and validation history in graph form, evaluate the results of the model, test and determine the accuracy of a prediction. The training loss is a metric used to assess how a deep learning model fits the training data, while validation loss is a metric used to assess the performance of a deep learning model on the validation set. The importance of this is to show the model's performance and identify which aspects need tuning. After you train your CNN model, you need to evaluate its performance on the validation set. This is important as it measures how close your predictions are to the actual values. Finally, we make predictions on the test data and the accuracy of it. Some other evaluation methods include a pipeline, a classification report and a confusion matrix.

# %% [markdown]
# ##  **INTERPRETATION OF RESULTS**

# %% [markdown]
# For this part we show the train and validation history, evaluate the model, and test and determine the accuracy of a prediction. For the first part being the accuracy of a prediction, we use a pipeline to fit the CNN Model and to test it on one prediction, the result of which came back as true. For the next part being train and validation history, we quote the figures of accuracy, val_accuracy, loss, and val_loss. We used 10 epochs of the data to fit the model and scores came back as:<br>
# *accuracy*[0.8455, 0.9043, 0.9184, 0.9269, 0.9340, 0.9397, 0.9444, 0.9481, 0.9528, 0.9545], <br>
# *val_accuracy*[0.8906, 0.9167, 0.9159, 0.9056, 0.9123, 0.9294, 0.9295, 0.9107, 0.9196, 0.9107], <br>
#  *loss*[0.3511, 0.2387, 0.2053, 0.1858, 0.1683, 0.1542, 0.1424, 0.1323, 0.1218, 0.1150], <br>
#  and *val_loss*[0.2622, 0.2095, 0.2094, 0.2312, 0.2182, 0.1822, 0.1841, 0.2515, 0.2260, 0.2679]. From the first graph for train and validation history, it shows accuracy and val_accuracy. The accuracy increases with the number of epochs and the val_accuracy decreases, this is good. The reason why the accuracy increases is because with each time the model is running the data it becomes more accurate, while val_accuracy might be attributed to the model having a low accuracy despite having high accuracy on the training data. The next graph depicts loss and val_loss. It shows loss decreasing and val_loss increasing, there is something off with the data. Both theses graphs depict the model's training loss decreases (accuracy increases) and the validation loss increases (accuracy decreases), which is a clear sign that there is overfitting. Overfitting is when the model can't generalise and fits too closely to the training dataset instead. Next we have the classification report.  The classification report prints back the precision, recall, f1 score, and support. The precision will be how many are correctly classified among that class; while recall means how many of this class you find over the whole number of element of this class. The f1 score is the harmonic mean between precision & recall; while support is the number of occurence of the given class in your dataset. When conducting the classification report, the results came back as [0.83, 0.95, 0.89, 10000] for class 0; and [0.94, 0.81, 0.87, 10000] for class 1. The precision score at class 0 is good (with 0.83 or 83%), and good at class 1 (0.94 or 94%). While recall score at class 0 is very good (with 0.95 or 95%), and good at class 1 (0.81 or 81%). F1 score at class 0 is also very good (with 0.89 or 89%), and good at class 1 (0.87 or 87%). Finally, for the confusion matrix it is made up of four quadrants: the False Negative (Top-Left Quadrant); the False Positive (Top-Right Quadrant); the True Negative (Bottom-Left Quadrant); and the True Positive (Bottom-Right Quadrant). From the results that came back from the confusion matrix, it found that there are 9484 False Negative, 516 False Positive, 1947 True Negative, and 8053 True Positive. False Negative means the predicted value was falsely predicted and that the actual value is positive,  and there were 9484 of these predictions. For False Positive the value of predictions is 516, this means the predicted value was predicted as true but was actually negative. While for True Negative the value of predictions is 1947, this means that the predicted value matches the actual value which was negative. Then, for True Positive the value of predictions is 8053, this means that the predicted values was predicted as true and is actually true.
#
# *Conclusion:* this dataset fitted with CNN Model has yielded some pretty good and accurate results. However, looking at the results from the confusion matrix, this model maybe overfitted. Therefore, some ways to improve upon this model in the future is maybe introduce Transfer Learning and Data Augmentation. Transfer learning involves the use of a pre-trained model, hese models can be used as a base for your model. Most models are so good that you won't need to add convolutional and pooling Layers. Data augmentation is artificially boosting the diversity and number of training examples by performing random transformations to existing images to create a set of new variants. While data augmentation is especially useful when the original training data set is relatively small. There are many more ways to improve upon this image classification model and should be taken into consideration in future research and other coding projects.

# %% [markdown]
# ##  **CODE**

# %% [markdown]
# ###  **Loading the Dataset**

# %% [markdown]
# **Mounting your Google Drive**
# <br>
# <br>
# In this step, Google Colab will connect to your Google Drive, it will ask for permissions to connect with your Google account details.

# %%
#Code Borrowed from:
#Filemon
#2018
#Easiest way to download kaggle data in Google Colab
#Software: Python
#( Kaggle, link: https://www.kaggle.com/discussions/general/74235)

# MOUNT YOUR GOOGLE DRIVE FILES FOLLOWING CODE MAKE MOUNT YOUR GOOGLE DRIVE
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Upload Kaggle.json File**
# <br>
# <br>
# Here Google Colab will prompt you to upload your Kaggle.json account file.
# <br>To get this file first Login to Kaggle > Click on your Account Icon on the Top Right > Click on Settings > Scroll down to API > first click Expire Token then Create New Token > the Kaggle.json file will Download automatically

# %%
# IMPORT THAT WILL IMPORT FILES TO GOOGLE COLAB
from google.colab import files # WE'LL USE THIS IMPORT TO UPLOAD THE KAGGLE.JSON FILE

files.upload() # THIS WILL PROMPT YOU TO UPLOAD THE KAGGLE.JSON FILE
# Out:
#      <input type="file" id="files-a971dd44-a9ba-45e6-a89e-3340eadf7502" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a971dd44-a9ba-45e6-a89e-3340eadf7502">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# MAKE SURE KAGGLE.JSON FILE IS PRESENT
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 68 Nov 19 06:58 kaggle.json

# %% [markdown]
# **Download the Dataset from Kaggle**
# <br>
# <br>
# In this step, we'll download the Kaggle dataset, directly into Google Drive

# %%
# INSTALL KAGGLE API CLIENT
# !pip install -q kaggle

# %%
# KAGGLE API CLIENT EXPECTS THE FILE TO BE IN ~/.KAGGLE SO MOVE IT THERE
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# SET PERMISSIONS
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# CHECK YOUR DIRECTORY BEFORE DOWNLOADING THE DATASET
# !pwd
# Out:
# /content

# %%
# DOWNLOAD THE DATASET FROM KAGGLE USING A ZIP FILE
# !kaggle datasets download -d birdy654/cifake-real-and-ai-generated-synthetic-images
# Out:
# ...
#  77% 81.0M/105M [00:00<00:00, 131MB/s]
# 100% 105M/105M [00:00<00:00, 144MB/s]

# %%
# UNZIP THE DOWNLOADED
# !unzip cifake-real-and-ai-generated-synthetic-images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/REAL/4500 (10).jpg
#   inflating: train/REAL/4500 (2).jpg
#   inflating: train/REAL/4500 (3).jpg
#   inflating: train/REAL/4500 (4).jpg
#   inflating: train/REAL/4500 (5).jpg
#   inflating: train/REAL/4500 (6).jpg
#   inflating: train/REAL/4500 (7).jpg
#   inflating: train/REAL/4500 (8).jpg
#   inflating: train/REAL/4500 (9).jpg
#   inflating: train/REAL/4500.jpg
#   inflating: train/REAL/4501 (10).jpg
#   inflating: train/REAL/4501 (2).jpg
#   inflating: train/REAL/4501 (3).jpg
#   inflating: train/REAL/4501 (4).jpg
#   inflating: train/REAL/4501 (5).jpg
#   inflating: train/REAL/4501 (6).jpg
#   inflating: train/REAL/4501 (7).jpg
#   inflating: train/REAL/4501 (8).jpg
#   inflating: train/REAL/4501 (9).jpg
#   inflating: train/REAL/4501.jpg
#   inflating: train/REAL/4502 (10).jpg
#   inflating: train/REAL/4502 (2).jpg
#   inflating: train/REAL/4502 (3).jpg
#   inflating: train/REAL/4502 (4).jpg
# ...

# %% [markdown]
# ###  **Image Generators**

# %% [markdown]
# **Imports, Directories and Image Sizes**
# <br>
# <br>
# We start off by using Tensorflow and Keras for our image processing. Tensorflow is a useful tool in image proceessing, specifically TensorFlow is a robust deep learning framework, and Keras is a high-level API that provides a modular, easy-to-use, and organised interface to solve real-life deep learning problems.

# %%
# IMPORT THAT GENERATES BATCHES OF TENSOR IMAGE DATA WITH REAL-TIME DATA AUGMENTATION
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# DIRECTORIES
train_img_path = '/content/train' # TRAIN DIRECTORY
test_img_path = '/content/test' # TEST DIRECTORY

# IMAGE CONSTRAINTS OR SIZES

# WE SET WIDTH AND HEIGHT OF IMAGE TO 32
# SINCE WE'LL USE CNNs IN OUR ANALYSIS, WE NEED TO RESIZE THE IMAGES' HEIGHT/WIDTH BY A MULTIPLE OF THE FACTOR BY THE WHICH CNN REDUCES SPATIAL SIZE BY THE LAST LAYER
width,height = 32,32

# BATCH SIZE IS A NUMBER OF SAMPLES PROCESSED BEFORE THE MODEL IS UPDATED
batch_size = 32 # BATCH SIZE OF 32 GAVE US THE BEST RESULT

# %% [markdown]
# **Train Generator**
# <br>
# <br>
# This method will call all the train images from the train directory, and pass it through an image generator for processing and generating realistic images out of them.

# %%
# TRAIN GENERATOR METHOD
def train():

  # DECLARE A VARIABLE FOR THE TRAIN GENERATOR
  train_data_gen = ImageDataGenerator(rescale = 1.0/255) # WE DIVIDE AN IMAGE BY 255 TO GET A RANGE OF 0 TO 1
  # # FLOW TRAINING IMAGES IN 32 BATCHES USING TRAIN_DATA_GEN GENERATOR FROM THE TRAIN DIRECTORY
  train_Dataset = train_data_gen.flow_from_directory(
    train_img_path,
    target_size = (width,height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True)

  return train_Dataset # RETURN TRAINING IMAGES

# %%
# CREATE THE TRAIN GENERATOR OBJECT FOR CALLING
train = train()

# DISPLAY THE SIZE OF A TRAIN IMAGE
train.image_shape
# Out:
# Found 100000 images belonging to 2 classes.
# (32, 32, 3)

# %% [markdown]
# **Test Generator**
# <br>
# <br>
# This will call all the test images from the test directory, and pass it through an image generator for processing and generating realistic images out of them.

# %%
# METHOD FOR TEST GENERATOR
def test():

  # DECLARE A VARIABLE FOR THE TEST GENERATOR
  test_data_gen = ImageDataGenerator(rescale = 1.0/255) # WE DIVIDE AN IMAGE BY 255 TO GET A RANGE OF 0 TO 1

  # # FLOW VALIDATION OR TEST IMAGES IN BATCHES OF 32 USING TEST_DATA_GEN GENERATOR
  test_Dataset = test_data_gen.flow_from_directory(
    test_img_path,
    target_size = (width,height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = False)

  return test_Dataset # RETURN TEST IMAGES

# %%
# CREATE THE TEST GENERATOR OBJECT FOR CALLING
test = test()

# DISPLAY SIZE OF A TEST IMAGE
test.image_shape
# Out:
# Found 20000 images belonging to 2 classes.
# (32, 32, 3)

# %% [markdown]
# ###  **Convolutional Neural Network (CNN)**

# %% [markdown]
# **Building the CNN Model**
# <br>
# <br>
# A CNN is useful in finding patterns in images to recognise objects, classes, and categories. Therefore, we can say a CNN is our discriminator that takes an image and its respective target image and gives probability value for its similarity.

# %%
# IMPORTS FOR CREATING THE CNN MODEL
from tensorflow.keras import layers, models

# METHOD FOR CNN MODEK
def cnn():
  # DEFINE THE MODEL OBJECT
  model = models.Sequential()

  # CREATE CONVOLUTIONAL LAYERS
  # WE USE THESE LAYERS TO BLUR AND SHARPEN IMAGES, BUT ALSO TO PERFORM OTHER OPERATIONS
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(width, height, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))

  # FLATTEN LAYER
  # WE DO THIS TO MAKE THE MULTIDIMENSIONAL INPUT ONE-DIMENSIONAL
  model.add(layers.Flatten())

  # DENSE LAYERS
  # THESE CAN CLASSIFY IMAGES BASED ON OUTPUT FROM CONVOLUTIONAL LAYERS
  model.add(layers.Dense(256, activation='relu'))
  model.add(layers.Dropout(0.5))  # OPTIMAL DROPOUT FOR REGULARISATION
  model.add(layers.Dense(1, activation='sigmoid'))  # OUTPUT LAYER WITH ONE NEURON (BINARY CLASSIFICATION)

  # COMPILE THE MODEL
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

  # DISPLAY A SUMMARY OF THE MODEL ARCHITECTURE
  model.summary()

  return model # RETURN MODEL

# %%
# CREATE THE CNN MODEL OBJECT
CNN = cnn()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# ...
# Total params: 224833 (878.25 KB)
# Trainable params: 224833 (878.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Training the Model**
# <br>
# <br>
# Now we fit the CNN Model to the image data

# %%
# DECLARE A VARIABLE FOR FITTING THE MODEL
# THE NUMBER OF EPOCHS DETERMINES HOW A LEARNING ALGORITHM WILL WORK IN THE TRAINING DATASET
# VALIDATION SPLIT SPECIFIES HOW MUCH OF THE TRAINING DATA WILL BE USED
history = CNN.fit(train,
                    epochs=10,
                    validation_data=test)
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 187s 59ms/step - loss: 0.3511 - accuracy: 0.8455 - val_loss: 0.2622 - val_accuracy: 0.8906
# Epoch 2/10
# 3125/3125 [==============================] - 197s 63ms/step - loss: 0.2387 - accuracy: 0.9043 - val_loss: 0.2095 - val_accuracy: 0.9167
# Epoch 3/10
# 3125/3125 [==============================] - 197s 63ms/step - loss: 0.2053 - accuracy: 0.9184 - val_loss: 0.2094 - val_accuracy: 0.9159
# Epoch 4/10
# 3125/3125 [==============================] - 188s 60ms/step - loss: 0.1858 - accuracy: 0.9269 - val_loss: 0.2312 - val_accuracy: 0.9056
# Epoch 5/10
# 3125/3125 [==============================] - 193s 62ms/step - loss: 0.1683 - accuracy: 0.9340 - val_loss: 0.2182 - val_accuracy: 0.9123
# Epoch 6/10
# 3125/3125 [==============================] - 198s 63ms/step - loss: 0.1542 - accuracy: 0.9397 - val_loss: 0.1822 - val_accuracy: 0.9294
# Epoch 7/10
# ...

# %% [markdown]
# ###  **Model Evaluation**

# %% [markdown]
# **Pipeline**
# <br>
# <br>
# A pipeline performs multiple operations in a sequence, for each element of an iterable, in such a way that the output of each element is the input of the next.

# %%
# IMPORT THE PIPELINE LIBRARY
from sklearn.pipeline import Pipeline

# DECLARE THE PIPELINE OBJECT BY PASSING THROUGH THE CNN MODEL
pipe = Pipeline(steps=[('CNN', cnn())])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# ...
# Total params: 224833 (878.25 KB)
# Trainable params: 224833 (878.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# FIT THE PIPELINE WITH TRAIN METHOD
pipe.fit(train)
# Out:
# 3125/3125 [==============================] - 177s 56ms/step - loss: 0.3394 - accuracy: 0.8529
# Pipeline(steps=[('CNN',
#                  <keras.src.engine.sequential.Sequential object at 0x78b420de58a0>)])

# %%
# FIT THE PIPELINE WITH TEST METHOD
pipe.fit(test)
# Out:
# 625/625 [==============================] - 34s 54ms/step - loss: 0.3591 - accuracy: 0.8457
# Pipeline(steps=[('CNN',
#                  <keras.src.engine.sequential.Sequential object at 0x78b420de58a0>)])

# %% [markdown]
# **Predictions**
# <br>
# <br>
# Here we test the accuracy of predictions

# %%
# DECLARE A VARIABLE FOR PREDICTIONS
predictions = pipe.predict(test)
# Out:
# 625/625 [==============================] - 13s 20ms/step

# %%
# THEN CREATE A VARIABLE FOR TESTING THE PREDICTIONS
binary_predictions = (predictions > 0.5).astype(int)

# DISPLAY THE TEST PREDICTIONS
binary_predictions
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
#Code Borrowed from:
#Coding-Lane
#2021
#Solution - CNN Image Classification.ipynb
#Software: Python
#(Github, link: https://github.com/Coding-Lane/Image-Classification-CNN-Keras/blob/main/Solution%20-%20CNN%20Image%20Classification.ipynb)

# TEST USING ONE OF THE PREDICTIONS
one_binary_predictions = (predictions > 0.5).astype(int).any()

if(one_binary_predictions == 0):
    pred = 'FAKE'
else:
    pred = 'REAL'

print("Our model says that this is a ", pred, " image") # THE PREDICTION CAME BACK AS TRUE OR A REAL IMAGE
one_binary_predictions
# Out:
# Our model says that this is a  REAL  image
# True

# %% [markdown]
# **Show Train and Validation History: Loss and Accuracy**
# <br>
# <br>
# Here we will display the model's total accuracy and loss

# %%
# USED FOR DISPLAYING THE INFORMATION OF GRAPHS: THE LABELS, THE VALUES, ETC.
import matplotlib.pyplot as plt

# VARIABLES FOR ACCURACY, LOSS, VALIDATION ACCURACY AND VALIDATION LOSS
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10) # EPOCH RANGE IS 10 BECAUSE MODEL WAS TRAINED WITH 10 EPOCHS

# PLOT THE GRAPH FOR TRAINING ACCURACY AND VALIDATION ACCURACY
plt.figure(figsize=(15, 15)) # SIZE OF THE GRAPH
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy') # LABEL
plt.plot(epochs_range, val_acc, label='Validation Accuracy') # LABEL
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy') # TITLE OF THE GRAPH

# PLOT THE GRAPH FOR TRAINING LOSS AND VALIDATION LOSS
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss') # LABEL
plt.plot(epochs_range, val_loss, label='Validation Loss') # LABEL
plt.legend(loc='upper right')
plt.title('Training and Validation Loss') # TITLE
plt.show() # DISPLAY THE TWO GRAPHS

# FOR THE FIRST GRAPH IT SHOWS THAT THE TRAINING ACCURACY IS HIGHER THAN VALIDATION ACCURACY

# FOR THE SECOND GRAPH IT SHOWS THE TRAINING LOSS IS HIGHER THAN THE VALIDATION LOSS

# %% [markdown]
# **Accuracy Score, Confusion Matrix and Classification Report**
# <br>
# <br>
# Here we evaluate the model's results using a classification report and a confusion matrix

# %%
# IMPORTS FOR CONFUSION MATRIX AND CLASSIFICATION REPORT
from sklearn.metrics import confusion_matrix, classification_report

# CREATE A VARIABLE FOR TRUE PREDICTIONS
true_labels = test.classes

# DISPLAY CLASSIFICATION REPORT
print(classification_report(true_labels, binary_predictions)) # WE PASS THROUGH THE true_labels AND binary_predictions

# PRECISION IS HOW MANY ARE CORRECTLY CLASSIFIED AMONG THAT CLASS
# RECALL IS HOW MANY HOW MANY OF THIS CLASS YOU FIND OVER THE WHOLE NUMBER OF ELEMENT OF THE CLASS
# SUPPORT IS THE NUMBER OF OCCURENCE OF THE GIVEN CLASS IN YOUR DATASET

# PRECISION SCORE AT CLASS 0 IS GOOD (WITH 0.83 OR 83%), AND GOOD AT CLASS 1 (0.94 OR 94%)
# RECALL SCORE AT CLASS 0 IS VERY GOOD (WITH 0.95 OR 95%), AND GOOD AT CLASS 1 (0.81 OR 81%)
# F1 SCORE AT CLASS 0 IS VERY GOOD (WITH 0.89 OR 89%), AND GOOD AT CLASS 1 (0.87 OR 87%)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89     10000
#            1       0.94      0.81      0.87     10000
#
#     accuracy                           0.88     20000
#    macro avg       0.88      0.88      0.88     20000
# weighted avg       0.88      0.88      0.88     20000

# %%
from sklearn import metrics # IMPORT FOR EVALUATING THE MODEL

# THE ACCURACY FOR OUR MODEL IS 0.87685 WHICH IS GOOD
print("=======Accuracy Score===========") # PRINTS THE ACCURACY SCORE FOR PREDICTIONS
print(metrics.accuracy_score(true_labels, binary_predictions)) # WE PASS THROUGH THE true_labels AND binary_predictions


print("=======Confision Matrix===========") # DISPLAYS THE PREDICTIONS IN A CONFUSION MATRIX
metrics.confusion_matrix(true_labels, binary_predictions) # WE PASS THROUGH THE true_labels AND binary_predictions
# Out:
# =======Accuracy Score===========
# 0.87685
# =======Confision Matrix===========
# array([[9484,  516],
#        [1947, 8053]])

# %%
import numpy as np # USED FOR STANDARD LINEAR ALGEBRA
import seaborn as sns # USED TO DISPLAY THE GRAPHICS OF GRAPHS

# THE CONFUSION MATRIX ALWAYS HAS AN ERROR WHEN DISPLAYING THE CORRECT NUMBER OF PREDICTIONS
# SO WE'LL DISPLAY THE PREDICTIONS FROM A NUMPY ARRAY
cm = np.array([[9484, 516],[1947, 8053]])

plt.xlabel('Predicted') # LABEL FOR X AXIS
plt.ylabel('True') # LABEL FOR Y AXIS

# CONFUSION MATRIX FOR PREDICTIONS
sns.heatmap(cm, annot=True,fmt="d",cmap='Blues').set(title='Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# DISPLAYS CONFUSION MATRIX
plt.show()

# CONFUSION MATRIX QUADRANTS

# False Negative (Top-Left Quadrant)
# False Positive (Top-Right Quadrant)
# True Negative (Bottom-Left Quadrant)
# True Positive (Bottom-Right Quadrant)

# FROM THE DATA IT SHOWS THAT THERE ARE 9484 FN, 516 FP, 1947 TN, AND 8053 TP

# FOR 'FALSE NEGATIVE' THE VALUE OF PREDICTIONS IS 9484, THIS MEANS THE PREDICTED VALUE WAS FALSELY PREDICTED AND THAT THE ACTUAL VALUE IS POSITIVE
# FOR 'FALSE POSITIVE' THE VALUE OF PREDICTIONS IS 516, THIS MEANS THE PREDICTED VALUE WAS PREDICTED AS TRUE BUT WAS ACTUALLY NEGATIVE
# FOR 'TRUE NEGATIVE' THE VALUE OF PREDICTIONS IS 1947, THIS MEANS THAT THE PREDICTED VALUE MATCHES THE ACTUAL VALUE WHICH WAS NEGATIVE
# FOR 'TRUE POSITIVE' THE VALUE OF PREDICTIONS IS 8053, THIS MEANS THAT THE PREDICTED VALUES WAS PREDICTED AS TRUE AND IS ACTUALLY TRUE
